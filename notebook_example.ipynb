# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #FF8400; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Details at: https://github.com/hoangtrung020541/remote-ssh-kaggle-vscode.git</div>

# %% [markdown]
# # (Optional) Install Oh My Posh
#
# --- Made to beautify the terminal ---

# %%
# %cd /kaggle/working
# !git clone https://github.com/hoangtrung020541/personalized_styler.git
# %cd /kaggle/working/personalized_styler/oh_my_posh_linux
# !bash oh_my_posh.sh
# %cd /kaggle/working
# Out:
# /kaggle/working
# fatal: destination path 'personalized_styler' already exists and is not an empty directory.
# /kaggle/working/personalized_styler/oh_my_posh_linux
# curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
#
# ℹ️  Installing oh-my-posh for linux-amd64 in /usr/local/bin
# ⬇️  Downloading oh-my-posh from https://github.com/JanDeDobbeleer/oh-my-posh/releases/latest/download/posh-linux-amd64
# curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# 🎨 Installing oh-my-posh themes in /root/.cache/oh-my-posh/themes
#
# curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# 🚀 Installation complete.
#
# You can follow the instructions at https://ohmyposh.dev/docs/installation/prompt
# to setup your shell to use oh-my-posh.
#
# If you want to use a built-in theme, you can find them in the /root/.cache/oh-my-posh/themes directory:
#   oh-my-posh init {shell} --config /root/.cache/oh-my-posh/themes/{theme}.omp.json
#
# /kaggle/working

# %% [markdown]
# # Ngork & SSH

# %%
# SSH public key
public_key_path = 'https://raw.githubusercontent.com/hoangtrung020541/SSH_Key_public/main/authorized_keys'

# password = ''.join(random.choice(string.ascii_letters + string.digits) for i in range(20))
password = 'kaggle'

# Setup sshd
! apt-get install -qq -o=Dpkg::Use-Pty=0 openssh-server pwgen > /dev/null

# Setup authenticational
! echo root:$password | chpasswd
! mkdir /kaggle/working/.ssh
! wget -P /kaggle/working/.ssh $public_key_path
! chmod 700 /kaggle/working/.ssh
! chmod 600 /kaggle/working/.ssh/authorized_keys

# Config sshd server
! mkdir -p /var/run/sshd
! echo "Protocol 2" >> /etc/ssh/sshd_config
! echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
! echo "PasswordAuthentication no" >> /etc/ssh/sshd_config
! echo "TCPKeepAlive yes" >> /etc/ssh/sshd_config
! echo "X11Forwarding yes" >> /etc/ssh/sshd_config
! echo "X11DisplayOffset 10" >> /etc/ssh/sshd_config
! echo "AuthorizedKeysFile /kaggle/working/.ssh/authorized_keys" >> /etc/ssh/sshd_config
! echo "PubkeyAuthentication yes" >> /etc/ssh/sshd_config
! echo "IgnoreRhosts yes" >> /etc/ssh/sshd_config
! echo "HostbasedAuthentication no" >> /etc/ssh/sshd_config
! echo "PrintLastLog yes" >> /etc/ssh/sshd_config
! echo "AcceptEnv LANG LC_*" >> /etc/ssh/sshd_config

! echo "LD_LIBRARY_PATH=/usr/lib64-nvidia" >> /root/.bashrc
! echo "export LD_LIBRARY_PATH" >> /root/.bashrc

# !ln -s /opt/conda/bin/* /bin/
# Out:
# E: Failed to fetch http://archive.ubuntu.com/ubuntu/pool/main/o/openssh/openssh-sftp-server_8.2p1-4ubuntu0.7_amd64.deb  404  Not Found [IP: 91.189.91.82 80]
# E: Failed to fetch http://archive.ubuntu.com/ubuntu/pool/main/o/openssh/openssh-server_8.2p1-4ubuntu0.7_amd64.deb  404  Not Found [IP: 91.189.91.82 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# mkdir: cannot create directory ‘/kaggle/working/.ssh’: File exists
# --2023-10-05 18:48:23--  https://raw.githubusercontent.com/hoangtrung020541/SSH_Key_public/main/authorized_keys
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 577 [text/plain]
# Saving to: ‘/kaggle/working/.ssh/authorized_keys.3’
#
# authorized_keys.3   100%[===================>]     577  --.-KB/s    in 0s
#
# 2023-10-05 18:48:23 (14.8 MB/s) - ‘/kaggle/working/.ssh/authorized_keys.3’ saved [577/577]
#
# ln: failed to create symbolic link '/bin/acyclic': File exists
# ln: failed to create symbolic link '/bin/bcomps': File exists
# ln: failed to create symbolic link '/bin/bunzip2': File exists
# ln: failed to create symbolic link '/bin/bzcat': File exists
# ln: failed to create symbolic link '/bin/bzcmp': File exists
# ln: failed to create symbolic link '/bin/bzdiff': File exists
# ln: failed to create symbolic link '/bin/bzegrep': File exists
# ln: failed to create symbolic link '/bin/bzfgrep': File exists
# ln: failed to create symbolic link '/bin/bzgrep': File exists
# ln: failed to create symbolic link '/bin/bzip2': File exists
# ln: failed to create symbolic link '/bin/bzip2recover': File exists
# ln: failed to create symbolic link '/bin/bzless': File exists
# ln: failed to create symbolic link '/bin/bzmore': File exists
# ln: failed to create symbolic link '/bin/c_rehash': File exists
# ln: failed to create symbolic link '/bin/captoinfo': File exists
# ln: failed to create symbolic link '/bin/ccomps': File exists
# ln: failed to create symbolic link '/bin/circo': File exists
# ln: failed to create symbolic link '/bin/clear': File exists
# ln: failed to create symbolic link '/bin/cluster': File exists
# ln: failed to create symbolic link '/bin/corelist': File exists
# ln: failed to create symbolic link '/bin/cpan': File exists
# ln: failed to create symbolic link '/bin/curl-config': File exists
# ln: failed to create symbolic link '/bin/dbus-cleanup-sockets': File exists
# ln: failed to create symbolic link '/bin/dbus-daemon': File exists
# ln: failed to create symbolic link '/bin/dbus-monitor': File exists
# ln: failed to create symbolic link '/bin/dbus-run-session': File exists
# ln: failed to create symbolic link '/bin/dbus-send': File exists
# ln: failed to create symbolic link '/bin/dbus-update-activation-environment': File exists
# ln: failed to create symbolic link '/bin/dbus-uuidgen': File exists
# ln: failed to create symbolic link '/bin/delaunay': File exists
# ln: failed to create symbolic link '/bin/diffimg': File exists
# ln: failed to create symbolic link '/bin/dijkstra': File exists
# ln: failed to create symbolic link '/bin/dot': File exists
# ln: failed to create symbolic link '/bin/dot2gxl': File exists
# ln: failed to create symbolic link '/bin/dot_builtins': File exists
# ln: failed to create symbolic link '/bin/edgepaint': File exists
# ln: failed to create symbolic link '/bin/enc2xs': File exists
# ln: failed to create symbolic link '/bin/encguess': File exists
# ln: failed to create symbolic link '/bin/fc-cache': File exists
# ln: failed to create symbolic link '/bin/fc-cat': File exists
# ln: failed to create symbolic link '/bin/fc-conflist': File exists
# ln: failed to create symbolic link '/bin/fc-list': File exists
# ln: failed to create symbolic link '/bin/fc-match': File exists
# ln: failed to create symbolic link '/bin/fc-pattern': File exists
# ln: failed to create symbolic link '/bin/fc-query': File exists
# ln: failed to create symbolic link '/bin/fc-scan': File exists
# ln: failed to create symbolic link '/bin/fc-validate': File exists
# ln: failed to create symbolic link '/bin/fdp': File exists
# ln: failed to create symbolic link '/bin/gapplication': File exists
# ln: failed to create symbolic link '/bin/gc': File exists
# ln: failed to create symbolic link '/bin/gdbus': File exists
# ln: failed to create symbolic link '/bin/gio': File exists
# ln: failed to create symbolic link '/bin/gio-querymodules': File exists
# ln: failed to create symbolic link '/bin/glib-compile-schemas': File exists
# ln: failed to create symbolic link '/bin/gml2gv': File exists
# ln: failed to create symbolic link '/bin/graphml2gv': File exists
# ln: failed to create symbolic link '/bin/gresource': File exists
# ln: failed to create symbolic link '/bin/gsettings': File exists
# ln: failed to create symbolic link '/bin/gtk-update-icon-cache': File exists
# ln: failed to create symbolic link '/bin/gts-config': File exists
# ln: failed to create symbolic link '/bin/gts2dxf': File exists
# ln: failed to create symbolic link '/bin/gts2oogl': File exists
# ln: failed to create symbolic link '/bin/gts2stl': File exists
# ln: failed to create symbolic link '/bin/gtscheck': File exists
# ln: failed to create symbolic link '/bin/gtscompare': File exists
# ln: failed to create symbolic link '/bin/gtstemplate': File exists
# ln: failed to create symbolic link '/bin/gv2gml': File exists
# ln: failed to create symbolic link '/bin/gv2gxl': File exists
# ln: failed to create symbolic link '/bin/gvcolor': File exists
# ln: failed to create symbolic link '/bin/gvgen': File exists
# ln: failed to create symbolic link '/bin/gvmap': File exists
# ln: failed to create symbolic link '/bin/gvmap.sh': File exists
# ln: failed to create symbolic link '/bin/gvpack': File exists
# ln: failed to create symbolic link '/bin/gvpr': File exists
# ln: failed to create symbolic link '/bin/gxl2dot': File exists
# ln: failed to create symbolic link '/bin/gxl2gv': File exists
# ln: failed to create symbolic link '/bin/h2ph': File exists
# ln: failed to create symbolic link '/bin/h2xs': File exists
# ln: failed to create symbolic link '/bin/h5c++': File exists
# ln: failed to create symbolic link '/bin/h5cc': File exists
# ln: failed to create symbolic link '/bin/h5fc': File exists
# ln: failed to create symbolic link '/bin/iconv': File exists
# ln: failed to create symbolic link '/bin/infocmp': File exists
# ln: failed to create symbolic link '/bin/infotocap': File exists
# ln: failed to create symbolic link '/bin/instmodsh': File exists
# ln: failed to create symbolic link '/bin/json_pp': File exists
# ln: failed to create symbolic link '/bin/libnetcfg': File exists
# ln: failed to create symbolic link '/bin/libpng-config': File exists
# ln: failed to create symbolic link '/bin/libpng16-config': File exists
# ln: failed to create symbolic link '/bin/lzcat': File exists
# ln: failed to create symbolic link '/bin/lzcmp': File exists
# ln: failed to create symbolic link '/bin/lzdiff': File exists
# ln: failed to create symbolic link '/bin/lzegrep': File exists
# ln: failed to create symbolic link '/bin/lzfgrep': File exists
# ln: failed to create symbolic link '/bin/lzgrep': File exists
# ln: failed to create symbolic link '/bin/lzless': File exists
# ln: failed to create symbolic link '/bin/lzma': File exists
# ln: failed to create symbolic link '/bin/lzmainfo': File exists
# ln: failed to create symbolic link '/bin/lzmore': File exists
# ln: failed to create symbolic link '/bin/mm2gv': File exists
# ln: failed to create symbolic link '/bin/neato': File exists
# ln: failed to create symbolic link '/bin/nop': File exists
# ln: failed to create symbolic link '/bin/openssl': File exists
# ln: failed to create symbolic link '/bin/osage': File exists
# ln: failed to create symbolic link '/bin/patchwork': File exists
# ln: failed to create symbolic link '/bin/perl': File exists
# ln: failed to create symbolic link '/bin/perlbug': File exists
# ln: failed to create symbolic link '/bin/perldoc': File exists
# ln: failed to create symbolic link '/bin/perlivp': File exists
# ln: failed to create symbolic link '/bin/perlthanks': File exists
# ln: failed to create symbolic link '/bin/piconv': File exists
# ln: failed to create symbolic link '/bin/pip': File exists
# ln: failed to create symbolic link '/bin/pip3': File exists
# ln: failed to create symbolic link '/bin/pkg-config': File exists
# ln: failed to create symbolic link '/bin/pl2pm': File exists
# ln: failed to create symbolic link '/bin/pod2html': File exists
# ln: failed to create symbolic link '/bin/pod2man': File exists
# ln: failed to create symbolic link '/bin/pod2text': File exists
# ln: failed to create symbolic link '/bin/pod2usage': File exists
# ln: failed to create symbolic link '/bin/podchecker': File exists
# ln: failed to create symbolic link '/bin/protoc': File exists
# ln: failed to create symbolic link '/bin/prove': File exists
# ln: failed to create symbolic link '/bin/prune': File exists
# ln: failed to create symbolic link '/bin/ptar': File exists
# ln: failed to create symbolic link '/bin/ptardiff': File exists
# ln: failed to create symbolic link '/bin/ptargrep': File exists
# ln: failed to create symbolic link '/bin/pydoc3': File exists
# ln: failed to create symbolic link '/bin/python3': File exists
# ln: failed to create symbolic link '/bin/reset': File exists
# ln: failed to create symbolic link '/bin/sccmap': File exists
# ln: failed to create symbolic link '/bin/sfdp': File exists
# ln: failed to create symbolic link '/bin/shasum': File exists
# ln: failed to create symbolic link '/bin/splain': File exists
# ln: failed to create symbolic link '/bin/stl2gts': File exists
# ln: failed to create symbolic link '/bin/tabs': File exists
# ln: failed to create symbolic link '/bin/tic': File exists
# ln: failed to create symbolic link '/bin/toe': File exists
# ln: failed to create symbolic link '/bin/tput': File exists
# ln: failed to create symbolic link '/bin/transform': File exists
# ln: failed to create symbolic link '/bin/tred': File exists
# ln: failed to create symbolic link '/bin/tset': File exists
# ln: failed to create symbolic link '/bin/twopi': File exists
# ln: failed to create symbolic link '/bin/unflatten': File exists
# ln: failed to create symbolic link '/bin/unlzma': File exists
# ln: failed to create symbolic link '/bin/unxz': File exists
# ln: failed to create symbolic link '/bin/xsubpp': File exists
# ln: failed to create symbolic link '/bin/xz': File exists
# ln: failed to create symbolic link '/bin/xzcat': File exists
# ln: failed to create symbolic link '/bin/xzcmp': File exists
# ln: failed to create symbolic link '/bin/xzdiff': File exists
# ln: failed to create symbolic link '/bin/xzegrep': File exists
# ln: failed to create symbolic link '/bin/xzfgrep': File exists
# ln: failed to create symbolic link '/bin/xzgrep': File exists
# ln: failed to create symbolic link '/bin/xzless': File exists
# ln: failed to create symbolic link '/bin/xzmore': File exists
# ln: failed to create symbolic link '/bin/zipdetails': File exists

# %%
# !sudo apt-get update --allow-releaseinfo-change

# %%
# Only run for the first time when creating this notebook
# %cd /kaggle/working
# !git clone https://github.com/hoangtrung020541/remote-ssh-kaggle-vscode.git
# Out:
# /kaggle/working
# Cloning into 'remote-ssh-kaggle-vscode'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 80 (delta 22), reused 62 (delta 10), pack-reused 0
# Unpacking objects: 100% (80/80), 1.56 MiB | 4.85 MiB/s, done.

# %%
# Required: After running this tile, stop and run again

# %cd /kaggle/working/remote-ssh-kaggle-vscode
# !bash install_ssh_server.sh public_key_path

# Copy authtoken from https://dashboard.ngrok.com/auth
# !bash add_ngrok_token.sh 2JRqL5IIUxrBWgosvYV2XmzSXTp_4pMNpGztPuBQKnYh3DxFs
# Out:
# /kaggle/working/remote-ssh-kaggle-vscode
# public_key_path
# --2023-10-05 18:53:45--  http://public_key_path/
# Resolving public_key_path (public_key_path)... failed: Name or service not known.
# wget: unable to resolve host address ‘public_key_path’
# --2023-10-05 18:53:45--  https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# Resolving bin.equinox.io (bin.equinox.io)... 54.237.133.81, 54.161.241.46, 52.202.168.65, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.237.133.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8752388 (8.3M) [application/octet-stream]
# Saving to: ‘ngrok-v3-stable-linux-amd64.tgz’
#
# ngrok-v3-stable-lin 100%[===================>]   8.35M  4.34MB/s    in 1.9s
#
# 2023-10-05 18:53:48 (4.34 MB/s) - ‘ngrok-v3-stable-linux-amd64.tgz’ saved [8752388/8752388]
#
# ngrok
# Get:1 http://packages.cloud.google.com/apt gcsfuse-focal InRelease [5023 B]
# Hit:2 https://packages.cloud.google.com/apt cloud-sdk InRelease
# Hit:3 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Fetched 5023 B in 1s (4533 B/s)33m
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 115 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# openssh-server is already the newest version (1:8.2p1-4ubuntu0.9).
# 0 upgraded, 0 newly installed, 0 to remove and 115 not upgraded.
#  * Restarting OpenBSD Secure Shell server sshd
#    ...done.
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !bash run_ssh_server.sh
# Out:
# 7=ngrok                                                           (Ctrl+C to quit)                                                                                Session Status                connecting                                        Version                       3.3.5                                             Latency                       -                                                 Web Interface                 http://127.0.0.1:4040                                                                                                             Connections                   ttl     opn     rt1     rt5     p50     p90                                     0       0       0.00    0.00    0.00    0.00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Introducing Always-On Global Server Load Balancer: https://ngrok.com/r/gslb                                    Session Status                onlineAccou      oangtrung02054@gmail.com (Plan: Free)Version                       3.3.5Region     AsiaPacific(ap)                               Latency-                                               Web Interface                 http://127.0.0.1:4040Forwarding                    tcp://0.tcp.ap.ngrok.io:10209 -> localhost:22Connections                   ttl     opn     rt1     rt5     p50     p90                                   0       0       0.00    0.00    0.00    0.00    47ms5487554750248715321111.111.1208.49 31468>
